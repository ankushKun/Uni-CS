# %%
import numpy as np
import matplotlib.pyplot as plt
#PCM Marks of the Team Members
w= 0.2

Physics = [79,80,78,33,64] 
Chemistry = [80,75,79,33,64]
Math = [78,72,82,34,60]
x_axis = np.arange(5)
plt.bar(x_axis+0.10,Physics,w,label='physics',color='blue')
plt.bar(x_axis+0.30,Chemistry,w,label='chemistry',color='orange')
plt.bar(x_axis-0.10,Math,w,label='math',color='red')
plt.xticks(x_axis-0.15,['Arpita', 'Simran', 'Aryan', 'Kamal', 'Priyanshi'])
plt.xlabel('Student Names')
plt.ylabel('Marks Obtained by the Students')
plt.title('PCM marks of the Students')
plt.legend(['Physics', 'Chemistry', 'Math'])
plt.show()
