# %%
# !pip3 install -U pip
# Out:
# ...
#   Using cached pip-22.3.1-py3-none-any.whl (2.1 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 20.1.1
#     Uninstalling pip-20.1.1:
#       Successfully uninstalled pip-20.1.1
# ...

# %%
# !pip3 install rasa --user
# Out:
# ...
#   Using cached rasa-3.4.0-py3-none-any.whl (821 kB)
# ...
#   Using cached SQLAlchemy-1.4.45-cp310-cp310-macosx_10_15_x86_64.whl (1.6 MB)
# ...
#   Using cached google_auth-2.15.0-py2.py3-none-any.whl (177 kB)
# ...
#   Using cached Sanic_Cors-2.0.1-py2.py3-none-any.whl (17 kB)
# ...
#   Using cached jsonpickle-2.2.0-py2.py3-none-any.whl (39 kB)
# ...
#   Using cached jsonschema-4.16.0-py3-none-any.whl (83 kB)
# ...
#   Using cached randomname-0.1.5-py3-none-any.whl
# ...
#   Using cached pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# ...
#   Using cached dask-2022.10.2-py3-none-any.whl (1.1 MB)
# ...
#   Using cached scipy-1.8.1-cp310-cp310-macosx_12_0_universal2.macosx_10_9_x86_64.whl (55.7 MB)
# ...
#   Using cached matplotlib-3.5.3-cp310-cp310-macosx_10_9_x86_64.whl (7.3 MB)
# ...
#   Using cached twilio-7.14.2-py2.py3-none-any.whl (1.4 MB)
# ...
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# ...
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# ...
#   Using cached tensorflow_text-2.8.2-cp310-cp310-macosx_10_9_x86_64.whl (4.0 MB)
# ...

# %%
# !python3 -m rasa init
